# %% [markdown]
# # Compare Sr $5s5s \rightarrow 5snl$ matrix elements with NIST

# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import numpy as np

import rydstate

# %% [markdown]
# ## NIST reference values
#
# The NIST ASD line strength of an E1 transition is $S = |\langle J \Vert d \Vert J' \rangle|^2$ in atomic units $(e\,a_0)^2$,
# so it is directly comparable to the square of rydstate's reduced matrix elements.

# %%
# {(n, s_tot): S in (e a0)^2} from https://physics.nist.gov/PhysRefData/ASD/lines_form.html (retrieved 2026-07-24)
nist_s = {
    (5, 0): 2.91e1,
    (6, 0): 7.1e-2,
    (7, 0): 1.3e-1,
    (8, 0): 3.5e-1,
    (9, 0): 2.09e-1,
    (10, 0): 1.2e-1,
    (11, 0): 6.3e-2,
    (12, 0): 4.0e-2,
    (13, 0): 2.57e-2,
    (14, 0): 1.89e-2,
    (15, 0): 1.4e-2,
    (16, 0): 1.0e-2,
    (17, 0): 7.9e-3,
    (18, 0): 6.6e-3,
    (19, 0): 5.0e-3,
    (20, 0): 4.01e-3,
}

# %% [markdown]
# ## Bare vs. full operator
#
# The full matrix element (including the symmetry factor $\sqrt{2}$) is used automatically if "electric_dipole" is specified.
# The symmetry factor applies because exactly one of the two states, the $5s5s$ ground state, has both of its valence
# electrons in the same shell, see `RydbergKet.valence_electrons_are_in_the_same_shell`.
#
# The $\sqrt{2}$ enters every contribution to the matrix element, so it cannot be switched off via the `part` argument
# (`part="rydberg"` selects only the contribution of the Rydberg electron, but still includes the $\sqrt{2}$).
# To compute the bare values for comparison, we therefore overwrite the cached
# `valence_electrons_are_in_the_same_shell` of the ground state, i.e. we treat the two valence electrons
# as distinguishable.

# %%
n_max = 30
matrix_elements: dict[str, dict[tuple[int, float], float]] = {}

for potential in ["coulomb", "fei_2009"]:
    basis_ns = rydstate.BasisSQDT("Sr88", n=(0, n_max), l_r=(0, 0), potential_class=potential)
    ground_state = basis_ns.sort_states("nu").states[0]
    basis_np = rydstate.BasisSQDT("Sr88", n=(0, n_max), l_r=(1, 1), potential_class=potential)

    matrix_elements[potential + " - full"] = {
        (state.n, state.calc_exp_qn("s_tot")): state.calc_reduced_matrix_element(
            ground_state, "electric_dipole", unit="e a0"
        )
        for state in basis_np.states
    }

    for ket in ground_state.rydberg_kets:  # ignore the symmetry factor for the bare matrix elements
        ket.__dict__["valence_electrons_are_in_the_same_shell"] = False
    matrix_elements[potential + " - bare"] = {
        (state.n, state.calc_exp_qn("s_tot")): state.calc_reduced_matrix_element(
            ground_state, "electric_dipole", unit="e a0"
        )
        for state in basis_np.states
    }
    for ket in ground_state.rydberg_kets:  # restore the cached property
        del ket.__dict__["valence_electrons_are_in_the_same_shell"]
# Out:
# The wavefunction for the radial_ket RadialKet(nu=2.127979643626841, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 0 nodes, but should have 3 nodes.
# The wavefunction for the radial_ket RadialKet(nu=1.545675122591217, potential=PotentialCoulombStrontium88(l_r=0)) has some issues:
#       The wavefunction has 1 nodes, but should have 4 nodes.
#       The integration for l=0 did stop at 0.31 (should be close to zero).
# The wavefunction for the radial_ket RadialKet(nu=3.045213644985167, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 1 nodes, but should have 4 nodes.
# The wavefunction for the radial_ket RadialKet(nu=3.9522901100766417, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 2 nodes, but should have 5 nodes.
# The wavefunction for the radial_ket RadialKet(nu=5.6236817451158005, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 4 nodes, but should have 6 nodes.
# The wavefunction for the radial_ket RadialKet(nu=6.491731900670257, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 5 nodes, but should have 7 nodes.
# The wavefunction for the radial_ket RadialKet(nu=7.418856305064204, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 6 nodes, but should have 8 nodes.
# The wavefunction for the radial_ket RadialKet(nu=8.37221815884094, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 7 nodes, but should have 9 nodes.
# The wavefunction for the radial_ket RadialKet(nu=9.346279622264944, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 8 nodes, but should have 10 nodes.
# The wavefunction for the radial_ket RadialKet(nu=10.329455102826303, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 9 nodes, but should have 11 nodes.
# The wavefunction for the radial_ket RadialKet(nu=11.317831826476322, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 10 nodes, but should have 12 nodes.
# The wavefunction for the radial_ket RadialKet(nu=12.310080802166087, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 11 nodes, but should have 13 nodes.
# The wavefunction for the radial_ket RadialKet(nu=13.302284823867543, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 12 nodes, but should have 14 nodes.
# The wavefunction for the radial_ket RadialKet(nu=14.297188901569285, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 13 nodes, but should have 15 nodes.
# The wavefunction for the radial_ket RadialKet(nu=15.293182210659385, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 14 nodes, but should have 16 nodes.
# The wavefunction for the radial_ket RadialKet(nu=16.289972518144626, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 15 nodes, but should have 17 nodes.
# The wavefunction for the radial_ket RadialKet(nu=17.287359805289437, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 16 nodes, but should have 18 nodes.
# The wavefunction for the radial_ket RadialKet(nu=18.285203378127346, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 17 nodes, but should have 19 nodes.
# The wavefunction for the radial_ket RadialKet(nu=19.283401893162083, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 18 nodes, but should have 20 nodes.
# The wavefunction for the radial_ket RadialKet(nu=20.281880815804744, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 19 nodes, but should have 21 nodes.
# The wavefunction for the radial_ket RadialKet(nu=21.280584311637018, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 20 nodes, but should have 22 nodes.
# The wavefunction for the radial_ket RadialKet(nu=22.279469865945003, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 21 nodes, but should have 23 nodes.
# The wavefunction for the radial_ket RadialKet(nu=23.278504630090985, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 22 nodes, but should have 24 nodes.
# The wavefunction for the radial_ket RadialKet(nu=24.27766288858316, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 23 nodes, but should have 25 nodes.
# The wavefunction for the radial_ket RadialKet(nu=25.276924270023173, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 24 nodes, but should have 26 nodes.
# The wavefunction for the radial_ket RadialKet(nu=26.276272461957472, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 25 nodes, but should have 27 nodes.
# The wavefunction for the radial_ket RadialKet(nu=27.275694273432602, potential=PotentialCoulombStrontium88(l_r=1)) has some issues:
#       The wavefunction has 26 nodes, but should have 28 nodes.
# The wavefunction for the radial_ket RadialKet(nu=5.6236817451158005, potential=PotentialFei2009Strontium88(l_r=1)) has some issues:
#       The wavefunction has 7 nodes, but should have 6 nodes.
# The wavefunction for the radial_ket RadialKet(nu=6.491731900670257, potential=PotentialFei2009Strontium88(l_r=1)) has some issues:
#       The wavefunction has 8 nodes, but should have 7 nodes.
# The wavefunction for the radial_ket RadialKet(nu=7.418856305064204, potential=PotentialFei2009Strontium88(l_r=1)) has some issues:
#       The wavefunction has 9 nodes, but should have 8 nodes.

# %% [markdown]
# ## Comparison plot
#
# Left: the matrix elements themselves.
# Right: the ratio of the calculated matrix elements to the NIST values.

# %%
fig, (ax_me, ax_ratio) = plt.subplots(1, 2, figsize=(12, 5))

colors = ["C0", "C0", "C1", "C1", "C2", "C2", "C3", "C3"]
linestyles = ["-", "--", "-", "--", "-", "--", "-", "--"]
markers = ["o", "s", "x", "s", "^", "v", "o", "s", "^", "v"]

s_tot = 0
s_tot_label = rf"$s_{{tot}}={s_tot}$"
n_nist = sorted(n for (n, _s_tot) in nist_s if _s_tot == s_tot)

for label, me in matrix_elements.items():
    n_list = [n for (n, _s_tot) in me if _s_tot == s_tot]
    style = {"color": colors.pop(0), "linestyle": linestyles.pop(0), "marker": markers.pop(0), "markersize": 4}
    ax_me.plot(n_list, [abs(me[(n, s_tot)]) for n in n_list], **style, label=f"{label}, {s_tot_label}")
    ax_ratio.plot(n_nist, np.abs([me[(n, s_tot)] / np.sqrt(nist_s[(n, s_tot)]) for n in n_nist]), **style)

ax_me.plot(
    n_nist,
    [np.sqrt(nist_s[(n, s_tot)]) for n in n_nist],
    color="k",
    linestyle="none",
    marker="X",
    markeredgecolor="black",
    fillstyle="none",
    label=f"NIST, {s_tot_label}",
)

ax_me.set_xscale("log")
ax_me.set_yscale("log")
ax_me.set_xticks([5, 6, 8, 10, 15, 20], labels=["5", "6", "8", "10", "15", "20"])
ax_me.set_xlabel("principal quantum number $n$")
ax_me.set_ylabel(r"$\sqrt{S_\mathrm{calc}} = |\langle 5s_{1/2} \Vert d \Vert np_j \rangle|$  ($e\,a_0$)")
ax_me.legend()

ax_ratio.axhline(1, color="gray", lw=0.8)
ax_ratio.set_xlabel("principal quantum number $n$")
ax_ratio.set_ylabel(r"$\sqrt{S_\mathrm{calc}} / \sqrt{S_\mathrm{NIST}}$")

plt.show()
